# %%
df = spark.read.csv("/Volumes/marathos/default/raw/country_codes.csv", header=True)
df.write.format("delta").saveAsTable("marathos.default.country_codes")

# %%
spark.table("marathos.default.country_codes").display()
